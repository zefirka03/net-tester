# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("./bench.csv", header=None)

# %%
df[0]
# Out:
# 0      4
# 1      5
# 2      6
# 3      7
# 4      8
# 5      9
# 6     10
# 7     11
# 8     12
# 9     13
# 10    14
# 11    15
# 12    16
# 13    17
# 14    18
# 15    19
# 16    20
# 17    21
# 18    22
# 19    23
# 20    24
# 21    25
# 22    26
# Name: 0, dtype: int64

# %%
plt.plot(df[0], df[1])
